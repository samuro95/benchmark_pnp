# %%
from benchopt import BaseDataset, safe_import_context
import random
import torch
from deepinv.physics import Denoising, GaussianNoise
import imageio.v3 as iio
import numpy as np
import glob

# %%
image_path = "./../data/images/BSD/train/"
random_state = 27
extension = ".png"
device = "cpu"
sigma = 0.1
n_samples = 10

# %%
it = 22

print("{:03d}".format(it))
# Out:
# 022

# %%
# Generate pseudorandom data using `numpy`.
random.seed(random_state)
torch.manual_seed(random_state)

# %%
# Load the data
file_list = list(glob.glob(image_path + "*" + extension))
random.shuffle(file_list)

# %%
# Load images into a list
gt_img_list = [] # torch.zeros(self.n_samples)
for it in range(n_samples):
    gt_img = np.array(
        iio.imread(file_list[it])
    )
    # Scale to [0,1]
    gt_img = (gt_img - gt_img.min())/(gt_img.max() - gt_img.min())

    gt_img_list.append(gt_img)

# %%
x = torch.tensor(
    np.array(gt_img_list), dtype=torch.float32, device=device
)

# %%
x = x[:,None,:,:]

# %%
# Define the forward model
physics = Denoising(noise=GaussianNoise(sigma))
# Generate the observations 
y = physics(x)

# %%
dict(x=x, y=y, physics=physics)
# Out:
# {'x': tensor([[[[0.9957, 0.9957, 0.9957,  ..., 0.1082, 0.1991, 0.2900],
#            [1.0000, 0.9957, 0.9957,  ..., 0.1385, 0.1169, 0.1732],
#            [1.0000, 1.0000, 1.0000,  ..., 0.1082, 0.1515, 0.1169],
#            ...,
#            [0.8312, 0.8658, 0.9048,  ..., 0.2294, 0.3463, 0.3680],
#            [0.8528, 0.8571, 0.8658,  ..., 0.2684, 0.3680, 0.2900],
#            [0.9221, 0.9394, 0.9870,  ..., 0.2814, 0.2814, 0.2554]]],
#
#
#          [[[0.6452, 0.6452, 0.6406,  ..., 0.6129, 0.6083, 0.6083],
#            [0.6406, 0.6406, 0.6359,  ..., 0.6129, 0.6129, 0.6129],
#            [0.6452, 0.6406, 0.6313,  ..., 0.6221, 0.6175, 0.6175],
#            ...,
#            [0.0276, 0.0276, 0.0276,  ..., 0.0783, 0.0922, 0.0876],
#            [0.0276, 0.0276, 0.0230,  ..., 0.1336, 0.1705, 0.1336],
#            [0.0276, 0.0276, 0.0276,  ..., 0.1659, 0.2166, 0.1843]]],
#
#
#          [[[0.4416, 0.4569, 0.4569,  ..., 0.1827, 0.1878, 0.1827],
#            [0.4569, 0.4721, 0.4721,  ..., 0.1929, 0.1827, 0.1777],
#            [0.4721, 0.4772, 0.4721,  ..., 0.1878, 0.1777, 0.1777],
#            ...,
#            [0.0863, 0.0812, 0.0812,  ..., 0.4822, 0.4822, 0.5381],
#            [0.0863, 0.0812, 0.0812,  ..., 0.4721, 0.4873, 0.5279],
#            [0.0863, 0.0812, 0.0812,  ..., 0.4873, 0.5025, 0.5127]]],
#
#
#          ...,
#
#
#          [[[0.6070, 0.6026, 0.5983,  ..., 0.6419, 0.6332, 0.6201],
#            [0.6070, 0.6026, 0.6026,  ..., 0.6332, 0.6288, 0.6245],
#            [0.6070, 0.6114, 0.6114,  ..., 0.6245, 0.6288, 0.6376],
#            ...,
#            [0.4061, 0.4934, 0.4891,  ..., 0.3057, 0.3057, 0.2969],
#            [0.4367, 0.4716, 0.5066,  ..., 0.3231, 0.2838, 0.2271],
#            [0.1747, 0.3843, 0.6332,  ..., 0.2969, 0.2664, 0.2402]]],
#
#
#          [[[0.2800, 0.3160, 0.3000,  ..., 0.4240, 0.3720, 0.3560],
#            [0.2920, 0.3080, 0.2920,  ..., 0.3560, 0.3520, 0.3360],
#            [0.3120, 0.3040, 0.3040,  ..., 0.3640, 0.3520, 0.3600],
#            ...,
#            [0.4560, 0.4200, 0.4520,  ..., 0.0640, 0.0720, 0.0880],
#            [0.3480, 0.2640, 0.3720,  ..., 0.2160, 0.2120, 0.2120],
#            [0.1280, 0.1160, 0.1040,  ..., 0.1960, 0.1960, 0.1920]]],
#
#
#          [[[0.5042, 0.5084, 0.5210,  ..., 0.6597, 0.6303, 0.6429],
#            [0.6513, 0.6555, 0.6639,  ..., 0.7017, 0.6765, 0.6681],
#            [0.7311, 0.7311, 0.7311,  ..., 0.7059, 0.7143, 0.7227],
#            ...,
#            [0.6345, 0.6387, 0.6345,  ..., 0.6471, 0.6471, 0.6387],
#            [0.6303, 0.6387, 0.6303,  ..., 0.6555, 0.6513, 0.6429],
#            [0.6261, 0.6303, 0.6303,  ..., 0.6597, 0.6555, 0.6513]]]]),
#  'y': tensor([[[[ 1.1528,  0.9183,  1.0961,  ...,  0.0806,  0.2317,  0.1446],
#            [ 0.8630,  0.9699,  1.0498,  ...,  0.1572,  0.2959,  0.1125],
#            [ 1.1373,  1.0999,  1.0026,  ...,  0.1937,  0.1547,  0.3231],
#            ...,
#            [ 0.7819,  0.7872,  0.9863,  ...,  0.0252,  0.3787,  0.5064],
#            [ 0.7516,  0.8177,  0.6641,  ...,  0.2071,  0.2780,  0.2034],
#            [ 0.9552,  1.0298,  0.7650,  ...,  0.3782,  0.3299,  0.4631]]],
#
#
#          [[[ 0.6529,  0.7370,  0.5682,  ...,  0.5362,  0.4371,  0.5822],
#            [ 0.7220,  0.6097,  0.6416,  ...,  0.5836,  0.7440,  0.5962],
#            [ 0.8049,  0.6292,  0.5969,  ...,  0.5913,  0.7530,  0.5056],
#            ...,
#            [ 0.0659,  0.0980,  0.0209,  ...,  0.2047,  0.1221,  0.2832],
#            [ 0.1005,  0.1643, -0.0799,  ...,  0.0691,  0.1949,  0.1220],
#            [-0.0311, -0.0850,  0.0451,  ...,  0.0372,  0.0871,  0.1917]]],
#
#
#          [[[ 0.4742,  0.5339,  0.3405,  ...,  0.2518,  0.2407,  0.2778],
#            [ 0.3774,  0.4370,  0.4611,  ...,  0.2412,  0.2795,  0.2535],
#            [ 0.5507,  0.5555,  0.3545,  ...,  0.1549,  0.0267,  0.3327],
#            ...,
#            [-0.0482,  0.1448,  0.0646,  ...,  0.5024,  0.5586,  0.5134],
#            [ 0.0419,  0.1628,  0.0112,  ...,  0.5378,  0.4124,  0.3900],
#            [ 0.1385,  0.0025,  0.0118,  ...,  0.5037,  0.4270,  0.3848]]],
#
#
#          ...,
#
#
#          [[[ 0.5992,  0.5518,  0.6447,  ...,  0.5603,  0.6144,  0.6082],
#            [ 0.6587,  0.7457,  0.6216,  ...,  0.6778,  0.6641,  0.6696],
#            [ 0.7059,  0.7144,  0.4734,  ...,  0.6226,  0.7079,  0.6899],
#            ...,
#            [ 0.5070,  0.5102,  0.3154,  ...,  0.3520,  0.2981,  0.2821],
#            [ 0.5066,  0.4384,  0.4359,  ...,  0.3254,  0.1252,  0.3205],
#            [ 0.1223,  0.4755,  0.7374,  ...,  0.2570,  0.0789,  0.0961]]],
#
#
#          [[[ 0.1937,  0.3690,  0.2194,  ...,  0.5479,  0.4318,  0.3327],
#            [ 0.2779,  0.3783,  0.2311,  ...,  0.3791,  0.3422,  0.2523],
#            [ 0.2195,  0.2221,  0.3645,  ...,  0.2115,  0.5361,  0.5174],
#            ...,
#            [ 0.4696,  0.5681,  0.3811,  ...,  0.0473,  0.1351,  0.0187],
#            [ 0.1867,  0.2666,  0.5306,  ...,  0.1792,  0.2319,  0.1440],
#            [ 0.0824,  0.1313,  0.0140,  ...,  0.3207,  0.4041,  0.1378]]],
#
#
#          [[[ 0.4855,  0.4403,  0.4528,  ...,  0.6663,  0.4586,  0.7043],
#            [ 0.4978,  0.4843,  0.5399,  ...,  0.7014,  0.3571,  0.5147],
#            [ 0.8142,  0.8285,  0.8204,  ...,  0.7699,  0.8619,  0.6299],
#            ...,
#            [ 0.5379,  0.6357,  0.8376,  ...,  0.6889,  0.6609,  0.5981],
#            [ 0.5699,  0.6987,  0.7185,  ...,  0.6926,  0.7727,  0.5924],
#            [ 0.6999,  0.6675,  0.4983,  ...,  0.6218,  0.5953,  0.4861]]]]),
#  'physics': Denoising(
#    (noise_model): GaussianNoise()
#  )}

# %%
x.shape
# Out:
# torch.Size([10, 1, 180, 180])

# %%
y.shape
# Out:
# torch.Size([10, 1, 180, 180])

# %%
physics
# Out:
# Denoising(
#   (noise_model): GaussianNoise()
# )

# %%
import deepinv as dinv
likelihood = dinv.optim.L2(sigma=physics.noise_model.sigma)

# %%
likelihood(x, y, physics)
# Out:
# tensor([16294.7803, 16295.4180, 16017.9814, 16102.9668, 16456.5098, 15978.1602,
#         16197.1289, 16365.1260, 16134.1201, 16148.5723])

# %%
prior = dinv.optim.ScorePrior(
                denoiser=dinv.models.DnCNN(
                    pretrained="download_lipschitz",
                    in_channels=1,
                    out_channels=1,
                    device="cpu"
                )
            )

print(prior)

print(x.shape)

prior.grad(x, physics.noise_model.sigma)
# Out:
# ScorePrior(
#   (denoiser): DnCNN(
#     (in_conv): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_list): ModuleList(
#       (0-17): 18 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (out_conv): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (nl_list): ModuleList(
#       (0-18): 19 x ReLU()
#     )
#   )
# )
# torch.Size([10, 1, 180, 180])
# tensor([[[[-1.2280e-01, -1.1879e-01,  9.8234e-02,  ..., -2.8033e-01,
#             2.3569e-01,  5.6019e-01],
#           [ 1.3737e-01, -1.2459e-01,  4.2325e-02,  ...,  4.5015e-01,
#            -6.7659e-01,  3.3575e-01],
#           [ 1.5595e-01,  2.5843e-01,  3.3464e-01,  ..., -6.9703e-01,
#             4.6601e-01, -5.0129e-01],
#           ...,
#           [-5.3582e-01, -4.1361e-01,  1.2338e-02,  ..., -6.9946e-01,
#             2.9644e-01,  5.7030e-01],
#           [-1.6011e-01,  1.9491e-02, -8.2583e-01,  ..., -3.8725e-02,
#             8.0482e-01, -5.4622e-01],
#           [-6.5970e-02, -1.3337e-01,  6.7149e-01,  ..., -9.8485e-02,
#            -4.8998e-02, -1.0541e-01]]],
#
#
#         [[[ 1.5827e-01,  3.8451e-01,  3.4815e-02,  ...,  5.5313e-02,
#            -1.4835e-01, -3.2859e-01],
#           [-1.9144e-01,  6.4850e-02, -1.2977e-01,  ..., -2.3425e-01,
#            -2.1195e-02, -2.0820e-01],
#           [ 1.3366e-01, -2.4992e-02, -6.7228e-01,  ...,  1.0828e-01,
#            -2.2799e-01, -2.1515e-01],
#           ...,
#           [ 9.5632e-02,  2.7571e-02,  1.1947e-01,  ..., -6.2989e-01,
#            -8.6813e-02, -5.0502e-01],
#           [ 1.3383e-01,  4.3410e-02, -3.1842e-01,  ..., -2.0616e-01,
#             5.5516e-01, -2.7546e-01],
#           [ 1.1845e-01, -8.9863e-03,  4.0533e-02,  ..., -8.4548e-02,
#             4.1269e-01,  6.7526e-02]]],
#
#
#         [[[-3.1908e-01,  2.0416e-01, -3.4377e-02,  ...,  1.2984e-01,
#             3.8397e-01,  4.9838e-02],
#           [-4.0813e-01,  3.8078e-01,  1.8530e-01,  ...,  1.0233e+00,
#            -6.1303e-03, -3.5935e-01],
#           [-5.5194e-03,  4.1255e-01,  2.7540e-01,  ...,  8.5593e-01,
#            -2.2843e-01, -3.3168e-01],
#           ...,
#           [ 3.6633e-01, -5.2182e-02, -3.0635e-02,  ...,  3.2751e-01,
#            -1.5973e-01,  5.7102e-01],
#           [ 2.2718e-01, -9.4507e-02,  3.7204e-02,  ..., -2.3390e-01,
#            -1.2152e-01,  1.7400e-01],
#           [ 1.5258e-01, -1.2795e-01, -3.0054e-02,  ...,  1.6599e-01,
#             1.0622e-01,  2.2030e-02]]],
#
#
#         ...,
#
#
#         [[[ 1.7130e-01,  4.2117e-02, -3.5430e-01,  ...,  6.4242e-01,
#             1.4570e-01, -5.8563e-01],
#           [-5.3954e-02, -3.6816e-01, -1.5115e-01,  ...,  9.3323e-02,
#            -1.5032e-01, -3.3412e-01],
#           [-1.8164e-01,  1.9993e-01,  4.5245e-01,  ..., -2.3181e-01,
#             1.1294e-01,  9.5721e-01],
#           ...,
#           [-2.4648e-01,  3.8121e-01,  1.6726e-01,  ...,  1.4538e-01,
#            -2.5615e-02,  8.9750e-02],
#           [ 4.9123e-01, -1.5369e-01,  1.7279e-02,  ...,  6.2277e-01,
#             1.1301e-02, -8.9518e-01],
#           [-5.0336e-01, -1.0414e-01,  5.7316e-01,  ..., -1.5377e-01,
#            -5.4994e-02, -2.9878e-02]]],
#
#
#         [[[-8.3177e-01,  7.5240e-01, -3.3994e-01,  ...,  4.2338e-01,
#            -2.0203e-01,  4.3339e-02],
#           [-4.0891e-01,  3.3702e-01, -6.5689e-01,  ..., -1.1505e-01,
#             1.2819e-01, -3.9716e-01],
#           [ 4.7792e-01, -1.8910e-02,  1.9925e-01,  ..., -6.1363e-03,
#            -1.8353e-01,  1.3082e-01],
#           ...,
#           [ 1.7752e-01,  4.9096e-02, -2.2778e-01,  ..., -9.8452e-01,
#            -4.6707e-01,  8.4751e-02],
#           [ 2.9978e-01, -4.2004e-01,  3.2124e-02,  ...,  5.4389e-04,
#             3.9127e-01,  5.1374e-01],
#           [-2.3049e-01,  4.8031e-02, -7.2217e-02,  ..., -1.5360e-01,
#             1.6785e-01, -1.4148e-01]]],
#
#
#         [[[-4.0656e-01, -1.5249e-01,  2.4449e-01,  ...,  1.3841e-01,
#            -9.5599e-01,  9.7418e-02],
#           [-1.9532e-02, -3.2556e-02,  1.1911e-01,  ...,  4.3474e-01,
#            -2.7569e-01, -4.2310e-01],
#           [ 2.7806e-01,  2.4744e-01, -3.7873e-02,  ..., -5.9733e-01,
#             3.7353e-01,  7.2975e-01],
#           ...,
#           [-1.1020e-01,  1.9187e-02, -3.2383e-01,  ...,  3.7218e-01,
#             2.9311e-01, -7.0226e-02],
#           [-1.7844e-01,  2.9807e-01, -6.4247e-01,  ...,  6.3186e-01,
#             1.6893e-01,  1.2016e-02],
#           [-3.7658e-01, -2.2757e-01, -5.7291e-01,  ...,  6.3068e-01,
#             1.8425e-01,  9.3794e-02]]]])
